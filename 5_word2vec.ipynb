# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.412837
# Nearest to known: templeton, celesta, vsl, isfahan, persuaded, fulfilling, dynasty, donut,
# Nearest to used: chapman, nightlife, cro, perhaps, peterson, germ, vegetal, nationale,
# Nearest to from: woe, juggling, immunosuppression, questions, fluid, cyrene, larkin, thorpe,
# Nearest to th: hallucinations, graced, jagged, anesthetics, intellectuals, clinic, ethnicity, maule,
# Nearest to when: wyman, unrequited, renounced, saloons, arminian, leppard, confucian, extensible,
# Nearest to time: began, patriarchs, moby, hippopotamus, lillee, linebarger, autodidacts, damme,
# Nearest to eight: juries, sewing, lynch, enters, commence, ji, fauna, csv,
# Nearest to be: voivodship, pringle, thermopylae, madrigal, disassembly, markup, tunes, ripening,
# Nearest to at: mop, drying, newtonian, merodach, cth, documenting, ecusa, goldbach,
# Nearest to world: erc, demarcated, waring, procellariiformes, fmri, certification, kinetoscope, spherical,
# Nearest to history: graffiti, fiske, knight, fresh, knotted, punt, yogurt, supplementation,
# Nearest to to: darlington, dangerous, constructing, tui, hymen, smitten, hearse, zones,
# Nearest to however: mz, clippers, repulsive, ashdown, paradoxes, irix, stiffness, adapting,
# Nearest to use: neutral, naturalists, biennial, clearing, marched, lunations, earrings, edom,
# Nearest to united: guadalcanal, berio, xxxii, stamens, preoccupation, pyramidal, forecasting, cadets,
# Nearest to it: grasshopper, gai, otc, rinnan, ebirah, renoir, chooses, abdulaziz,
# Average loss at step 2000: 4.366603
# Average loss at step 4000: 3.860721
# Average loss at step 6000: 3.790933
# Average loss at step 8000: 3.688408
# Average loss at step 10000: 3.615399
# Nearest to known: persuaded, preserved, divisibility, celesta, nanaimo, count, video, pommel,
# Nearest to used: chapman, blur, upscale, gesserit, nightlife, important, roar, found,
# Nearest to from: in, into, during, minds, through, at, inviting, with,
# Nearest to th: hallucinations, three, spiders, bankruptcy, wagons, figaro, five, hmas,
# Nearest to when: unrequited, ias, saloons, entries, soi, original, because, confucian,
# Nearest to time: began, moby, heracleidae, endpoints, lillee, prejudices, hippopotamus, groom,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to be: have, was, are, is, were, by, been, become,
# Nearest to at: in, newtonian, nicephorus, denounced, guerilla, from, of, documenting,
# Nearest to world: demarcated, singly, antonov, pedagogic, dragged, procellariiformes, opposes, couper,
# Nearest to history: samarium, graffiti, auk, knight, east, correctness, colloquium, prefectures,
# Nearest to to: not, would, bosman, sanger, unethical, easternmost, will, capsule,
# Nearest to however: round, clippers, paradoxes, noyce, katana, disallowed, vargas, adapting,
# Nearest to use: neutral, most, interchanged, lunations, pharmacies, treehouse, formulae, naturalised,
# Nearest to united: xxxii, guadalcanal, uniforms, foreshadowed, parish, micas, acme, dolomite,
# Nearest to it: he, not, there, this, they, also, which, that,
# Average loss at step 12000: 3.605775
# Average loss at step 14000: 3.572120
# Average loss at step 16000: 3.410229
# Average loss at step 18000: 3.456428
# Average loss at step 20000: 3.542232
# Nearest to known: used, persuaded, preserved, such, divisibility, gesserit, celesta, denton,
# Nearest to used: found, known, gesserit, chapman, blur, seen, translated, debatable,
# Nearest to from: into, in, at, through, and, minds, with, climactic,
# Nearest to th: hallucinations, spiders, three, bankruptcy, wagons, bays, two, denial,
# Nearest to when: if, because, ias, though, why, since, was, following,
# Nearest to time: began, years, heracleidae, suspects, endpoints, lillee, year, charset,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to be: have, was, been, is, by, were, being, become,
# Nearest to at: in, on, from, newtonian, guerilla, dried, anonymously, suspects,
# Nearest to world: pedagogic, myung, antonov, demarcated, holberg, couper, procellariiformes, quipped,
# Nearest to history: colloquium, prefectures, gillespie, samarium, development, correctness, extravagant, chai,
# Nearest to to: not, bosman, would, will, cannot, can, germania, may,
# Nearest to however: but, that, there, vargas, adapting, collingwood, noyce, before,
# Nearest to use: most, danced, treehouse, neutral, right, formulae, zener, play,
# Nearest to united: xxxii, acme, uniforms, parish, foreshadowed, micas, hildesheim, guadalcanal,
# Nearest to it: he, there, she, they, this, which, not, we,
# Average loss at step 22000: 3.501446
# Average loss at step 24000: 3.493435
# Average loss at step 26000: 3.479630
# Average loss at step 28000: 3.476884
# Average loss at step 30000: 3.500572
# Nearest to known: used, preserved, persuaded, such, regarded, gesserit, defined, described,
# Nearest to used: known, found, seen, given, gesserit, translated, viewed, described,
# Nearest to from: into, in, and, climactic, of, during, rasmussen, through,
# Nearest to th: hallucinations, one, eight, bc, seven, figaro, spiders, wagons,
# Nearest to when: if, after, though, while, was, because, soi, before,
# Nearest to time: heracleidae, endpoints, years, suspects, hunt, god, line, village,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to be: have, been, universalist, being, are, is, were, become,
# Nearest to at: in, anonymously, dried, on, during, newtonian, guerilla, receiver,
# Nearest to world: myung, quipped, demarcated, couper, holberg, pedagogic, christus, attest,
# Nearest to history: development, colloquium, gillespie, staying, samarium, dieting, topics, formulations,
# Nearest to to: would, can, will, bosman, could, briefly, attachments, should,
# Nearest to however: but, although, while, that, where, collingwood, vargas, kestrel,
# Nearest to use: most, spirit, naturalised, wh, play, neutral, superoxide, zener,
# Nearest to united: xxxii, uniforms, acme, principal, parish, guadalcanal, foreshadowed, dietrich,
# Nearest to it: he, there, she, this, they, which, also, not,
# Average loss at step 32000: 3.500921
# Average loss at step 34000: 3.498544
# Average loss at step 36000: 3.454449
# Average loss at step 38000: 3.298383
# Average loss at step 40000: 3.429290
# Nearest to known: used, regarded, such, preserved, described, gesserit, persuaded, defined,
# Nearest to used: found, known, given, seen, applied, referred, described, held,
# Nearest to from: into, climactic, through, during, after, despite, under, inviting,
# Nearest to th: hallucinations, seven, three, bc, ikea, eight, one, figaro,
# Nearest to when: if, while, after, though, before, where, by, since,
# Nearest to time: year, years, charset, partido, heracleidae, way, lockhart, suspects,
# Nearest to eight: nine, seven, six, five, four, three, zero, one,
# Nearest to be: have, been, being, were, is, was, are, become,
# Nearest to at: anonymously, on, newtonian, during, dried, over, towards, guerilla,
# Nearest to world: myung, quipped, panoramas, publishes, pedagogic, encephalopathy, connectors, attest,
# Nearest to history: development, colloquium, samarium, topics, list, theropod, extravagant, aol,
# Nearest to to: will, must, can, would, from, should, cannot, easternmost,
# Nearest to however: but, although, that, while, centerline, kestrel, even, before,
# Nearest to use: sense, most, impression, spirit, onyx, naturalised, luddites, variety,
# Nearest to united: uniforms, principal, xxxii, parish, guadalcanal, stamens, universalists, micas,
# Nearest to it: he, she, there, this, they, which, not, but,
# Average loss at step 42000: 3.430563
# Average loss at step 44000: 3.457839
# Average loss at step 46000: 3.452072
# Average loss at step 48000: 3.352568
# Average loss at step 50000: 3.384108
# Nearest to known: used, regarded, preserved, defined, described, possible, called, such,
# Nearest to used: known, seen, referred, found, given, applied, regarded, considered,
# Nearest to from: into, through, climactic, during, in, under, across, hurricanes,
# Nearest to th: three, hallucinations, bc, one, five, six, martian, ikea,
# Nearest to when: if, after, while, though, where, before, although, but,
# Nearest to time: day, year, way, partido, kristian, danann, procedural, approval,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to be: have, been, being, was, were, become, produce, universalist,
# Nearest to at: during, towards, on, tomography, hussein, dried, newtonian, anonymously,
# Nearest to world: myung, attracted, quipped, holberg, connectors, panoramas, pronunciation, fortnight,
# Nearest to history: extravagant, development, samarium, list, aol, topics, euripides, dragon,
# Nearest to to: bosman, can, must, pinocchio, would, could, against, shores,
# Nearest to however: but, although, while, that, when, where, though, before,
# Nearest to use: sense, most, surface, impression, spirit, inns, formulae, study,
# Nearest to united: uniforms, parish, reliably, acme, micas, universalists, lehmann, principal,
# Nearest to it: he, she, there, this, they, denarius, not, still,
# Average loss at step 52000: 3.437232
# Average loss at step 54000: 3.427860
# Average loss at step 56000: 3.434576
# Average loss at step 58000: 3.396208
# Average loss at step 60000: 3.397834
# Nearest to known: used, regarded, such, defined, called, possible, preserved, persuaded,
# Nearest to used: known, seen, referred, written, applied, given, described, regarded,
# Nearest to from: into, through, under, within, in, climactic, despite, hurricanes,
# Nearest to th: bc, five, four, six, rd, one, eight, hallucinations,
# Nearest to when: if, although, while, after, where, before, though, because,
# Nearest to time: case, way, day, year, recommended, values, representation, partido,
# Nearest to eight: six, nine, four, seven, five, three, zero, one,
# Nearest to be: been, have, is, being, become, was, refer, are,
# Nearest to at: in, tomography, under, during, guerilla, lucca, flexible, riley,
# Nearest to world: myung, holberg, measurable, dragged, biblioth, panoramas, hudson, nfl,
# Nearest to history: list, development, besieging, topics, gillespie, economy, samarium, period,
# Nearest to to: would, bosman, should, may, must, not, overs, will,
# Nearest to however: but, although, while, that, before, when, ontological, yakov,
# Nearest to use: sense, most, surface, tian, inns, case, impression, afford,
# Nearest to united: parish, principal, lehmann, uniforms, reliably, universalists, footage, micas,
# Nearest to it: he, she, there, this, which, they, tlatoani, still,
# Average loss at step 62000: 3.242609
# Average loss at step 64000: 3.249959
# Average loss at step 66000: 3.402540
# Average loss at step 68000: 3.394775
# Average loss at step 70000: 3.359882
# Nearest to known: used, regarded, defined, such, called, described, seen, preserved,
# Nearest to used: known, seen, regarded, written, described, found, applied, referred,
# Nearest to from: into, through, within, climactic, under, despite, beyond, alimony,
# Nearest to th: bc, rd, hallucinations, pelagianism, juggernaut, solzhenitsyn, ikea, gideon,
# Nearest to when: if, while, where, before, although, however, though, after,
# Nearest to time: case, year, simplifies, day, idea, lockhart, however, representation,
# Nearest to eight: nine, six, seven, four, five, zero, three, one,
# Nearest to be: been, become, is, have, being, were, was, are,
# Nearest to at: during, replicators, newtonian, guerilla, noticeable, under, talladega, djinn,
# Nearest to world: myung, panoramas, dragged, ecologically, pedagogic, pronunciation, holberg, tapu,
# Nearest to history: list, development, extravagant, period, magyars, euripides, gillespie, dragon,
# Nearest to to: will, would, must, bosman, should, for, germania, not,
# Nearest to however: although, but, while, though, that, where, when, vulgaris,
# Nearest to use: most, sense, impression, surface, size, spirit, tian, consist,
# Nearest to united: parish, principal, footage, domitius, lehmann, uncontrollable, exclude, reindeer,
# Nearest to it: he, she, there, this, they, we, tlatoani, denarius,
# Average loss at step 72000: 3.379453
# Average loss at step 74000: 3.347685
# Average loss at step 76000: 3.327307
# Average loss at step 78000: 3.353286
# Average loss at step 80000: 3.380604
# Nearest to known: used, regarded, defined, called, described, preserved, such, seen,
# Nearest to used: known, seen, referred, found, written, described, given, regarded,
# Nearest to from: through, into, within, in, under, despite, between, climactic,
# Nearest to th: bc, eight, pelagianism, six, rd, five, juggernaut, gideon,
# Nearest to when: if, before, though, after, while, during, where, although,
# Nearest to time: year, day, lockhart, case, publisher, idea, simplifies, representation,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to be: been, being, become, have, produce, are, were, refer,
# Nearest to at: in, on, replicators, guerilla, rhodesian, during, cataloguing, allotment,
# Nearest to world: myung, pronunciation, panoramas, fortnight, dragged, largest, pablo, attest,
# Nearest to history: list, development, magyars, origin, dragon, microbial, argumentation, period,
# Nearest to to: will, bosman, would, should, must, may, could, can,
# Nearest to however: but, although, that, while, though, where, when, particularly,
# Nearest to use: sense, most, tian, naturalised, consist, implication, spirit, impression,
# Nearest to united: footage, parish, mandela, ods, principal, xxxii, uniforms, acme,
# Nearest to it: he, she, there, this, they, we, itself, never,
# Average loss at step 82000: 3.407429
# Average loss at step 84000: 3.409833
# Average loss at step 86000: 3.393757
# Average loss at step 88000: 3.353775
# Average loss at step 90000: 3.368679
# Nearest to known: used, regarded, such, described, defined, seen, called, possible,
# Nearest to used: known, referred, seen, considered, applied, found, given, regarded,
# Nearest to from: through, into, under, despite, across, during, beyond, alimony,
# Nearest to th: bc, four, seven, rd, one, juggernaut, eight, six,
# Nearest to when: if, while, after, before, where, although, during, though,
# Nearest to time: day, lockhart, case, representation, simplifies, publisher, year, pathologic,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to be: been, become, was, have, being, is, produce, easily,
# Nearest to at: during, in, towards, tomography, on, under, guerilla, signaling,
# Nearest to world: myung, biblioth, attest, dragged, pedagogic, shot, cold, person,
# Nearest to history: list, period, magyars, nova, dragon, origin, development, microbial,
# Nearest to to: bosman, would, chalcolithic, alms, will, must, helices, osamu,
# Nearest to however: but, although, that, though, while, especially, where, raises,
# Nearest to use: most, sense, tian, observe, naturalised, because, share, support,
# Nearest to united: footage, parish, mandela, uniforms, ods, micas, reindeer, erick,
# Nearest to it: he, she, there, this, they, tlatoani, we, never,
# Average loss at step 92000: 3.398587
# Average loss at step 94000: 3.251882
# Average loss at step 96000: 3.356994
# Average loss at step 98000: 3.244955
# Average loss at step 100000: 3.355245
# Nearest to known: such, used, regarded, defined, possible, described, seen, called,
# Nearest to used: referred, known, seen, applied, considered, found, given, written,
# Nearest to from: in, through, into, climactic, beyond, despite, during, tremor,
# Nearest to th: bc, rd, juggernaut, nd, solzhenitsyn, gideon, pelagianism, shear,
# Nearest to when: if, while, where, although, though, after, before, during,
# Nearest to time: day, year, lockhart, representation, way, simplifies, differing, publisher,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to be: been, become, being, have, is, are, was, refer,
# Nearest to at: on, in, during, aragorn, guerilla, after, tomography, cataloguing,
# Nearest to world: myung, attest, dragged, pedagogic, pablo, globin, pronunciation, unep,
# Nearest to history: list, nova, magyars, microbial, dragon, period, sheepdog, inscribed,
# Nearest to to: will, bosman, should, must, would, shall, could, easternmost,
# Nearest to however: but, although, that, though, especially, while, and, when,
# Nearest to use: sense, observe, tian, most, share, support, chick, fit,
# Nearest to united: footage, parish, ods, antelope, uniforms, universalists, mandela, corinthian,
# Nearest to it: he, she, this, there, they, never, which, goldwater,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ## CBOW的tensorflow 实现
# ![CBOW结构](http://i2.wp.com/www.thushv.com/wp-content/uploads/2016/12/cbow.png)

# %%
#生成batch
def generate_batch2(batch_size, skip_window):
    global data_index
    #assert skip_window%2==1  
    
    span = 2*skip_window + 1
    
    batchs = np.ndarray(shape = (batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape = (batch_size, 1), dtype=np.int32)
    
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(batch_size): 
        target = skip_window
        labels[i] = buffer[target]
        targets_to_avoid = [target]
        
        col = 0
        for j in range(span):
            if j == span // 2:
                continue
            batchs[i, col] = buffer[j]
            col = col + 1
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return (batchs,labels)

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch2(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', [[reverse_dictionary[batch[row,col]] for col in range(batch.shape[1])] for row in range(batch.shape[0])])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
